# %% [markdown]
# # Descriptive Analytics and Data Preprocessing on Sales & Discounts Dataset

# %% [markdown]
# # #Descriptive Analytics for Numerical Columns

# %% [raw]
# Load the dataset into a data analysis tool or programming environment (e.g., Python with pandas library).

# %%
import pandas as pd

df=pd.read_csv("sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %% [raw]
# Identify numerical columns in the dataset. Calculate the mean, median, mode, and standard deviation for these columns.

# %%
numerical_columns = df.select_dtypes(include=['int64','float64'])
print(numerical_columns)
print("Can simply use describe function for this")
print(numerical_columns.describe())
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# ...

# %% [raw]
# There are 450 observations for each numerical column in the dataset, which means there are no missing values. The average number of units sold is about 5, with most sales being around 4. Some high values do make the range bigger. The average price and total sales value are much higher than their medians. This means that there are high-value outliers that are affecting the mean. The standard deviations for price and sales are big, which means that these values can change a lot. The discount rate is usually around 15% and doesn't change much, which shows that the store has consistent discount policies. The discount amount and net sales value vary widely, which is due to differences in the sizes of the transactions. In general, the data shows that there are both small and very large sales transactions with stable discount rates.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # #Histograms

# %%
import matplotlib.pyplot as plt

numerical_cols = df.select_dtypes(include='number')

numerical_columns.hist(figsize=(10,8))
plt.show()

# %% [markdown]
# # #Box Plots

# %%
import seaborn as sns

plt.figure(figsize=(10,6))
sns.boxplot(data=numerical_columns)
plt.show()

# %% [markdown]
# # #Bar Charts

# %%
categorical_cols = df.select_dtypes(include='object')
for col in categorical_cols:
    df[col].value_counts().plot(kind='bar')
    plt.title(col)
    plt.show()

# %% [markdown]
# # Conclusion

# %% [raw]
# The descriptive analysis shows that sales-related variables like Avg Price, Total Sales Value, Discount Amount, and Net Sales Value have a lot of variation and are right-skewed. This means that there are some transactions with very high values. The histograms show that most of the values are in the lower ranges, with a few extreme values, which confirms this skewness. The boxplots show that there are a lot of outliers, especially in Total Sales Value and Net Sales Value. This suggests that people sometimes make big purchases. The discount rate stays pretty steady, mostly between 15% and 20%. This shows that the company has a consistent discount strategy. Based on the categorical analysis, brands like Jeera show up the most, while other brands show up less often. The business units (Mobiles, FMCG, Lifestyle) have distributions that are pretty even.
